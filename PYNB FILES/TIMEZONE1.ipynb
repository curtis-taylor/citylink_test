# %%
import requests
import pandas as pd
import json
import datetime

cityname = ["London", "Toronto", "Rome", "Sydney"]
country = ["United Kingdom", "Canada", "Italy", "Australia"]
region = ["City of London, Greater London", "Ontario", "Lazio", "New South Wales"]


key = "5f7c9d283060480d857194323212906"

count = 0

# Function to check for text terms in json info
def check_name(x, keyname, name): 
  checktext = '"{}":"{}"'.format(keyname, name)
  print("Name Search Term: {}".format(checktext))
  if checktext in x:
    print("{} found in json info".format(checktext))
  else:
    print("{} not found in json info: json appears to be not valid".format(checktext))

#Function for datetime validation
def datetime_check(localtime_list, localtime_string):
  if len(localtime_list[0]) == 10 and len(localtime_list[1]):
     print(">> LOCALTIME DIGIT COUNT test PASS")
  else:
     print(">> LOCALTIME DIGIT COUNT NOT CORRECT!!!!!")

  date_stst = loamp_licaltime_list[0].split('-')
  time_stamp_list = localtime_list[0].split(':')

  print("YEAR is correct") if date_stamp_list[0] == "2021" else print("YEAR is INVALID")

  try:
    t = datetime.datetime.strptime(localtime_string,"%Y-%m-%d %H:%M")
    print("t: {}".format(t))
    print("LOCAL DATE is A VALID date")
  except ValueError:
    print("LOCAL DATE is INVALID date: FAIL")

# %%
for name in cityname:
  timezone = "http://api.weatherapi.com/v1/current.json?key={}&q={}".format(key, cityname[count])
  x = requests.get(timezone)
  z = x.json()
  print(x.text)
  print("STATUS: {}".format(x))
  print("** LOCALTIME: {}".format(z['location']['localtime']))
  localtime_list = z['location']['localtime'].split(' ')

  datetime_check(localtime_list, z['location']['localtime'])

  print("Call Status for {} call: {}".format(name, x))
  check_name(x.text, "name", cityname[count])
  check_name(x.text, "country", country[count])
  check_name(x.text, "region", region[count])
  print("___")
  count = count + 1

  #data = json.x
# Out:
# {"location":{"name":"London","region":"City of London, Greater London","country":"United Kingdom","lat":51.52,"lon":-0.11,"tz_id":"Europe/London","localtime_epoch":1625158593,"localtime":"2021-07-01 17:56"},"current":{"last_updated_epoch":1625157900,"last_updated":"2021-07-01 17:45","temp_c":20.0,"temp_f":68.0,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":5.6,"wind_kph":9.0,"wind_degree":10,"wind_dir":"N","pressure_mb":1017.0,"pressure_in":30.5,"precip_mm":0.0,"precip_in":0.0,"humidity":60,"cloud":0,"feelslike_c":20.0,"feelslike_f":68.0,"vis_km":10.0,"vis_miles":6.0,"uv":5.0,"gust_mph":6.7,"gust_kph":10.8}}
# STATUS: <Response [200]>
# ** LOCALTIME: 2021-07-01 17:56
# >> LOCALTIME DIGIT COUNT test PASS
# YEAR is correct
# t: 2021-07-01 17:56:00
# LOCAL DATE is A VALID date
# Call Status for London call: <Response [200]>
# Name Search Term: "name":"London"
# "name":"London" found in json info
# Name Search Term: "country":"United Kingdom"
# "country":"United Kingdom" found in json info
# Name Search Term: "region":"City of London, Greater London"
# "region":"City of London, Greater London" found in json info
# ___
# {"location":{"name":"Toronto","region":"Ontario","country":"Canada","lat":43.67,"lon":-79.42,"tz_id":"America/Toronto","localtime_epoch":1625158594,"localtime":"2021-07-01 12:56"},"current":{"last_updated_epoch":1625157900,"last_updated":"2021-07-01 12:45","temp_c":22.0,"temp_f":71.6,"is_day":1,"condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/day/116.png","code":1003},"wind_mph":4.3,"wind_kph":6.8,"wind_degree":180,"wind_dir":"S","pressure_mb":1012.0,"pressure_in":30.4,"precip_mm":0.1,"precip_in":0.0,"humidity":78,"cloud":25,"feelslike_c":24.6,"feelslike_f":76.2,"vis_km":14.0,"vis_miles":8.0,"uv":5.0,"gust_mph":4.3,"gust_kph":6.8}}
# STATUS: <Response [200]>
# ** LOCALTIME: 2021-07-01 12:56
# >> LOCALTIME DIGIT COUNT test PASS
# YEAR is correct
# t: 2021-07-01 12:56:00
# LOCAL DATE is A VALID date
# Call Status for Toronto call: <Response [200]>
# Name Search Term: "name":"Toronto"
# "name":"Toronto" found in json info
# Name Search Term: "country":"Canada"
# "country":"Canada" found in json info
# Name Search Term: "region":"Ontario"
# "region":"Ontario" found in json info
# ___
# {"location":{"name":"Rome","region":"Lazio","country":"Italy","lat":41.9,"lon":12.48,"tz_id":"Europe/Rome","localtime_epoch":1625158594,"localtime":"2021-07-01 18:56"},"current":{"last_updated_epoch":1625157900,"last_updated":"2021-07-01 18:45","temp_c":29.0,"temp_f":84.2,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":10.5,"wind_kph":16.9,"wind_degree":250,"wind_dir":"WSW","pressure_mb":1013.0,"pressure_in":30.4,"precip_mm":0.0,"precip_in":0.0,"humidity":45,"cloud":0,"feelslike_c":28.2,"feelslike_f":82.8,"vis_km":10.0,"vis_miles":6.0,"uv":8.0,"gust_mph":14.5,"gust_kph":23.4}}
# STATUS: <Response [200]>
# ** LOCALTIME: 2021-07-01 18:56
# >> LOCALTIME DIGIT COUNT test PASS
# YEAR is correct
# t: 2021-07-01 18:56:00
# LOCAL DATE is A VALID date
# Call Status for Rome call: <Response [200]>
# Name Search Term: "name":"Rome"
# "name":"Rome" found in json info
# Name Search Term: "country":"Italy"
# "country":"Italy" found in json info
# Name Search Term: "region":"Lazio"
# "region":"Lazio" found in json info
# ___
# {"location":{"name":"Sydney","region":"New South Wales","country":"Australia","lat":-33.88,"lon":151.22,"tz_id":"Australia/Sydney","localtime_epoch":1625158594,"localtime":"2021-07-02 2:56"},"current":{"last_updated_epoch":1625157900,"last_updated":"2021-07-02 02:45","temp_c":12.0,"temp_f":53.6,"is_day":0,"condition":{"text":"Mist","icon":"//cdn.weatherapi.com/weather/64x64/night/143.png","code":1030},"wind_mph":4.3,"wind_kph":6.8,"wind_degree":300,"wind_dir":"WNW","pressure_mb":1018.0,"pressure_in":30.5,"precip_mm":0.1,"precip_in":0.0,"humidity":100,"cloud":75,"feelslike_c":11.0,"feelslike_f":51.8,"vis_km":4.0,"vis_miles":2.0,"uv":1.0,"gust_mph":9.4,"gust_kph":15.1}}
# STATUS: <Response [200]>
# ** LOCALTIME: 2021-07-02 2:56
# >> LOCALTIME DIGIT COUNT test PASS
# YEAR is correct
# t: 2021-07-02 02:56:00
# LOCAL DATE is A VALID date
# Call Status for Sydney call: <Response [200]>
# Name Search Term: "name":"Sydney"
# "name":"Sydney" found in json info
# Name Search Term: "country":"Australia"
# "country":"Australia" found in json info
# Name Search Term: "region":"New South Wales"
# "region":"New South Wales" found in json info
# ___
